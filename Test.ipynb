# %% [markdown]
# <a href="https://colab.research.google.com/github/gowrishjanapareddy/ai-mentor-portfolio/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hsi")
# Out:
# Hsi

# %%
# !pip install google-generativeai

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ["GEMINI_API_KEY"] = getpass.getpass("Paste Your Api Key Here:")
# Out:
# Paste Your Api Key Here:··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# Here are 4 short bullet points explaining the 5-Layer AI Skill Pyramid:
#
# *   **Progressive Framework:** It's a structured model illustrating the escalating skills needed for AI proficiency, moving from foundational understanding to strategic leadership.
# *   **Foundation (Layers 1-2):** Begins with **Data Fluency** (understanding data) and **Model Fluency** (grasping AI model types, capabilities, and limitations).
# *   **Application (Layers 3-4):** Moves to practical application through **AI Development** (building and training models) and **AI Deployment** (operationalizing models into real-world systems).
# *   **Leadership (Layer 5):** Culminates in **AI Strategy & Ethics**, focusing on the responsible implementation, governance, business impact, and societal implications of AI.
